# %% [markdown]
# # Capstone Project - The battle of the Neigborhoods (Week 2)
#
#
# Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of Contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#sesults)
# * [Conclusion](#conclusion)

# %% [markdown]
#  ## Introduction: Bussines Problem <a name="introduction"></a>

# %% [markdown]
# In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to stakeholders interested in opening an **Italian restaurant** in **Mexico City**, Mexico.
#
# Since there are lots of restaurants in Mexico City we will try to detect **locations that are not already crowded with restaurants**. We are also particularly interested in **areas with no Italian restaurants in vicinity**. We would also prefer locations **as close to city center as possible**, assuming that first two conditions are met.
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.
#
# This is essential for the results of this final task.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * number of and distance to Italian restaurants in the neighborhood, if any
# * distance of neighborhood from city center
#
# We decided to use regularly spaced grid of locations, centered around city center, to define our neighborhoods.
#
# Following data sources will be needed to extract/generate the required information:
# * centers of candidate areas will be generated algorithmically and approximate addresses of centers of those areas will be obtained using **Google Maps API reverse geocoding**
# * number of restaurants aMExico City their type and location in every neighborhood will be obtained using **Foursquare API**
# * coordinate of MExico City center will be obtained using **Google Maps API geocoding** of well known Mexico City location

# %% [markdown]
# ### Neighborhood Candidates on Mexico City

# %%
import random 
import numpy as np 
import pandas as pd 
import json 
import requests 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
from pandas.io.json import json_normalize 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium 
#!conda install -c conda-forge urllib2 --yes 
from sklearn.cluster import KMeans
print('All libraries are well imported!!.')
# Out:
# All libraries are well imported!!.

# %%
df = pd.read_csv('D:\curso Coursera\Curso 9 Proyecto Final\Semana 5\Capstone Project The Battle of Neighborhood Part 2\cdmx_Nuevo.csv')
df = df.drop(columns=['ENTIDAD', 'CVE_ALC', 'CVE_COL','SECC_COM', 'SECC_PAR', 'Geo Shape'])
df['latitud'], df['longitud'] = df['Geo Point'].str.split(',', 1).str
df = df.drop(columns=["Geo Point"])
column_names = ['Borough', 'Neighbourhood', 'Latitude', 'Longitude'] 
df.columns = column_names
df = df[-df.isnull().any(axis=1)]

# %%
df.describe()
# Out:
#                Borough Neighbourhood       Latitude        Longitude
# count             1808          1808           1808             1808
# unique            1739            16           1808             1808
# top     MIGUEL HIDALGO    IZTAPALAPA  19.2701801068   -99.1358247041
# freq                 4           293              1                1

# %%
map_neigb_mexicocity = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
            [lat, lng],
            radius=5,
            popup=label,
            color='blue',
            fill=True,
            fill_color='#3186cc',
            fill_opacity=0.7,
            parse_html=False).add_to(map_neigb_mexicocity)

# %%
map_neigb_mexicocity.save("map_neigb_mexicocity.html ") 
map_neigb_mexicocity
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
neighborhoods=pd.DataFrame(dict, columns=column_names, dtype=None)
neighborhoods
# Out:
#                      Borough  \
# 0             MIGUEL HIDALGO
# 1             MIGUEL HIDALGO
# 2             MIGUEL HIDALGO
# 3             MIGUEL HIDALGO
# 4             MIGUEL HIDALGO
# 5        VENUSTIANO CARRANZA
# 6                   COYOACAN
# 7                   COYOACAN
# 8                   COYOACAN
# 9        VENUSTIANO CARRANZA
# 10       VENUSTIANO CARRANZA
# 11       VENUSTIANO CARRANZA
# 12            MIGUEL HIDALGO
# 13            MIGUEL HIDALGO
# 14            MIGUEL HIDALGO
# 15       VENUSTIANO CARRANZA
# 16       VENUSTIANO CARRANZA
# 17       VENUSTIANO CARRANZA
# 18                  COYOACAN
# 19                  COYOACAN
# 20                  COYOACAN
# 21                  COYOACAN
# 22                  COYOACAN
# 23                  COYOACAN
# 24                  COYOACAN
# 25                  COYOACAN
# 26                  COYOACAN
# 27                  COYOACAN
# 28         GUSTAVO A. MADERO
# 29         GUSTAVO A. MADERO
# 30         GUSTAVO A. MADERO
# 31         GUSTAVO A. MADERO
# 32         GUSTAVO A. MADERO
# 33         GUSTAVO A. MADERO
# 34         GUSTAVO A. MADERO
# 35         GUSTAVO A. MADERO
# 36         GUSTAVO A. MADERO
# 37         GUSTAVO A. MADERO
# 38         GUSTAVO A. MADERO
# 39         GUSTAVO A. MADERO
# 40         GUSTAVO A. MADERO
# 41         GUSTAVO A. MADERO
# 42         GUSTAVO A. MADERO
# 43                   TLALPAN
# 44                   TLALPAN
# 45                   TLALPAN
# 46                   TLALPAN
# 47                   TLALPAN
# 48                XOCHIMILCO
# 49                XOCHIMILCO
# 50                XOCHIMILCO
# 51                XOCHIMILCO
# 52                XOCHIMILCO
# 53                   TLALPAN
# 54                   TLALPAN
# 55                   TLALPAN
# 56                   TLALPAN
# 57                   TLALPAN
# 58                   TLALPAN
# 59         GUSTAVO A. MADERO
# 60         GUSTAVO A. MADERO
# 61         GUSTAVO A. MADERO
# 62                XOCHIMILCO
# 63                XOCHIMILCO
# 64                   TLALPAN
# 65                   TLALPAN
# 66                   TLALPAN
# 67                   TLALPAN
# 68                   TLALPAN
# 69                 IZTACALCO
# 70              AZCAPOTZALCO
# 71            ALVARO OBREGON
# 72            ALVARO OBREGON
# 73                   TLAHUAC
# 74              AZCAPOTZALCO
# 75              AZCAPOTZALCO
# 76            ALVARO OBREGON
# 77            ALVARO OBREGON
# 78            ALVARO OBREGON
# 79            ALVARO OBREGON
# 80            ALVARO OBREGON
# 81            ALVARO OBREGON
# 82            ALVARO OBREGON
# 83            ALVARO OBREGON
# 84              AZCAPOTZALCO
# 85            ALVARO OBREGON
# 86            ALVARO OBREGON
# 87                   TLAHUAC
# 88                 IZTACALCO
# 89                 IZTACALCO
# 90            ALVARO OBREGON
# 91            ALVARO OBREGON
# 92                IZTAPALAPA
# 93                IZTAPALAPA
# 94                IZTAPALAPA
# 95                IZTAPALAPA
# 96                IZTAPALAPA
# 97                IZTAPALAPA
# 98                IZTAPALAPA
# 99                IZTAPALAPA
# 100               IZTAPALAPA
# 101               IZTAPALAPA
# 102               IZTAPALAPA
# 103               IZTAPALAPA
# 104               IZTAPALAPA
# 105               IZTAPALAPA
# 106               IZTAPALAPA
# 107               IZTAPALAPA
# 108               IZTAPALAPA
# 109               IZTAPALAPA
# 110            BENITO JUAREZ
# 111    CUAJIMALPA DE MORELOS
# 112    CUAJIMALPA DE MORELOS
# 113    CUAJIMALPA DE MORELOS
# 114   LA MAGDALENA CONTRERAS
# 115   LA MAGDALENA CONTRERAS
# 116   LA MAGDALENA CONTRERAS
# 117               IZTAPALAPA
# 118               IZTAPALAPA
# 119               IZTAPALAPA
# 120            BENITO JUAREZ
# 121            BENITO JUAREZ
# 122            BENITO JUAREZ
# 123            BENITO JUAREZ
# 124               CUAUHTEMOC
# 125               CUAUHTEMOC
# 126               CUAUHTEMOC
# 127               CUAUHTEMOC
# 128           MIGUEL HIDALGO
# 129        GUSTAVO A. MADERO
# 130        GUSTAVO A. MADERO
# 131        GUSTAVO A. MADERO
# 132             AZCAPOTZALCO
# 133             AZCAPOTZALCO
# 134             AZCAPOTZALCO
# 135                  TLALPAN
# 136                  TLALPAN
# 137        GUSTAVO A. MADERO
# 138        GUSTAVO A. MADERO
# 139        GUSTAVO A. MADERO
# 140        GUSTAVO A. MADERO
# 141        GUSTAVO A. MADERO
# 142        GUSTAVO A. MADERO
# 143        GUSTAVO A. MADERO
# 144        GUSTAVO A. MADERO
# 145        GUSTAVO A. MADERO
# 146        GUSTAVO A. MADERO
# 147        GUSTAVO A. MADERO
# 148               XOCHIMILCO
# 149               XOCHIMILCO
# 150               XOCHIMILCO
# 151               XOCHIMILCO
# 152               XOCHIMILCO
# 153                  TLALPAN
# 154                  TLALPAN
# 155                  TLALPAN
# 156                  TLALPAN
# 157               XOCHIMILCO
# 158                  TLALPAN
# 159        GUSTAVO A. MADERO
# 160        GUSTAVO A. MADERO
# 161        GUSTAVO A. MADERO
# 162                  TLALPAN
# 163                  TLALPAN
# 164                IZTACALCO
# 165             AZCAPOTZALCO
# 166             AZCAPOTZALCO
# 167             AZCAPOTZALCO
# 168             AZCAPOTZALCO
# 169                  TLAHUAC
# 170                  TLAHUAC
# 171                  TLAHUAC
# 172                  TLAHUAC
# 173             AZCAPOTZALCO
# 174                IZTACALCO
# 175           ALVARO OBREGON
# 176             AZCAPOTZALCO
# 177             AZCAPOTZALCO
# 178           ALVARO OBREGON
# 179           ALVARO OBREGON
# 180           ALVARO OBREGON
# 181           ALVARO OBREGON
# 182               CUAUHTEMOC
# 183           ALVARO OBREGON
# 184               CUAUHTEMOC
# 185               CUAUHTEMOC
# 186           ALVARO OBREGON
# 187           ALVARO OBREGON
# 188           ALVARO OBREGON
# 189               CUAUHTEMOC
# 190               CUAUHTEMOC
# 191               IZTAPALAPA
# 192               IZTAPALAPA
# 193               IZTAPALAPA
# 194               CUAUHTEMOC
# 195               CUAUHTEMOC
# 196               IZTAPALAPA
# 197               IZTAPALAPA
# 198               IZTAPALAPA
# 199               IZTAPALAPA
# 200               IZTAPALAPA
# 201               IZTAPALAPA
# 202               IZTAPALAPA
# 203               IZTAPALAPA
# 204               IZTAPALAPA
# 205               IZTAPALAPA
# 206               IZTAPALAPA
# 207               IZTAPALAPA
# 208               IZTAPALAPA
# 209    CUAJIMALPA DE MORELOS
# 210    CUAJIMALPA DE MORELOS
# 211   LA MAGDALENA CONTRERAS
# 212   LA MAGDALENA CONTRERAS
# 213   LA MAGDALENA CONTRERAS
# 214            BENITO JUAREZ
# 215            BENITO JUAREZ
# 216            BENITO JUAREZ
# 217            BENITO JUAREZ
# 218            BENITO JUAREZ
# 219            BENITO JUAREZ
# 220           MIGUEL HIDALGO
# 221           MIGUEL HIDALGO
# 222           MIGUEL HIDALGO
# 223           MIGUEL HIDALGO
# 224           MIGUEL HIDALGO
# 225           MIGUEL HIDALGO
# 226           MIGUEL HIDALGO
# 227                 COYOACAN
# 228                 COYOACAN
# 229                 COYOACAN
# 230                 COYOACAN
# 231                 COYOACAN
# 232                 COYOACAN
# 233                 COYOACAN
# 234                 COYOACAN
# 235      VENUSTIANO CARRANZA
# 236      VENUSTIANO CARRANZA
# 237      VENUSTIANO CARRANZA
# 238      VENUSTIANO CARRANZA
# 239        GUSTAVO A. MADERO
# 240        GUSTAVO A. MADERO
# 241        GUSTAVO A. MADERO
# 242        GUSTAVO A. MADERO
# 243        GUSTAVO A. MADERO
# 244        GUSTAVO A. MADERO
# 245        GUSTAVO A. MADERO
# 246        GUSTAVO A. MADERO
# 247        GUSTAVO A. MADERO
# 248        GUSTAVO A. MADERO
# 249        GUSTAVO A. MADERO
# 250               XOCHIMILCO
# 251               XOCHIMILCO
# 252               XOCHIMILCO
# 253               MILPA ALTA
# 254               MILPA ALTA
# 255        GUSTAVO A. MADERO
# 256               XOCHIMILCO
# 257               XOCHIMILCO
# 258               XOCHIMILCO
# 259                  TLALPAN
# 260               XOCHIMILCO
# 261                  TLALPAN
# 262                  TLALPAN
# 263                  TLALPAN
# 264                  TLALPAN
# 265                  TLALPAN
# 266                  TLALPAN
# 267                  TLALPAN
# 268        GUSTAVO A. MADERO
# 269        GUSTAVO A. MADERO
# 270        GUSTAVO A. MADERO
# 271        GUSTAVO A. MADERO
# 272                  TLALPAN
# 273                  TLALPAN
# 274                  TLALPAN
# 275                IZTACALCO
# 276                  TLAHUAC
# 277                  TLAHUAC
# 278             AZCAPOTZALCO
# 279           ALVARO OBREGON
# 280             AZCAPOTZALCO
# 281             AZCAPOTZALCO
# 282             AZCAPOTZALCO
# 283             AZCAPOTZALCO
# 284                  TLAHUAC
# 285             AZCAPOTZALCO
# 286             AZCAPOTZALCO
# 287                  TLAHUAC
# 288             AZCAPOTZALCO
# 289               CUAUHTEMOC
# 290               CUAUHTEMOC
# 291               CUAUHTEMOC
# 292           ALVARO OBREGON
# 293           ALVARO OBREGON
# 294           ALVARO OBREGON
# 295           ALVARO OBREGON
# 296           ALVARO OBREGON
# 297           ALVARO OBREGON
# 298           ALVARO OBREGON
# 299           ALVARO OBREGON
# 300           ALVARO OBREGON
# 301           ALVARO OBREGON
# 302           ALVARO OBREGON
# 303           ALVARO OBREGON
# 304           ALVARO OBREGON
# 305           ALVARO OBREGON
# 306           ALVARO OBREGON
# 307           ALVARO OBREGON
# 308           ALVARO OBREGON
# 309                IZTACALCO
# 310                IZTACALCO
# 311                IZTACALCO
# 312                IZTACALCO
# 313                IZTACALCO
# 314               CUAUHTEMOC
# 315               CUAUHTEMOC
# 316               IZTAPALAPA
# 317               CUAUHTEMOC
# 318               CUAUHTEMOC
# 319                 COYOACAN
# 320           MIGUEL HIDALGO
# 321    CUAJIMALPA DE MORELOS
# 322    CUAJIMALPA DE MORELOS
# 323    CUAJIMALPA DE MORELOS
# 324    CUAJIMALPA DE MORELOS
# 325               IZTAPALAPA
# 326               IZTAPALAPA
# 327               IZTAPALAPA
# 328               IZTAPALAPA
# 329               IZTAPALAPA
# 330               IZTAPALAPA
# 331               IZTAPALAPA
# 332               IZTAPALAPA
# 333               IZTAPALAPA
# 334               IZTAPALAPA
# 335   LA MAGDALENA CONTRERAS
# 336   LA MAGDALENA CONTRERAS
# 337   LA MAGDALENA CONTRERAS
# 338   LA MAGDALENA CONTRERAS
# 339               IZTAPALAPA
# 340               IZTAPALAPA
# 341               IZTAPALAPA
# 342               IZTAPALAPA
# 343            BENITO JUAREZ
# 344            BENITO JUAREZ
# 345            BENITO JUAREZ
# 346            BENITO JUAREZ
# 347            BENITO JUAREZ
# 348           MIGUEL HIDALGO
# 349                 COYOACAN
# 350                 COYOACAN
# 351                 COYOACAN
# 352                 COYOACAN
# 353                 COYOACAN
# 354                 COYOACAN
# 355      VENUSTIANO CARRANZA
# 356      VENUSTIANO CARRANZA
# 357      VENUSTIANO CARRANZA
# 358                 COYOACAN
# 359                 COYOACAN
# 360                 COYOACAN
# 361                 COYOACAN
# 362                 COYOACAN
# 363           ALVARO OBREGON
# 364           ALVARO OBREGON
# 365                  TLAHUAC
# 366                  TLAHUAC
# 367                  TLAHUAC
# 368                  TLAHUAC
# 369                  TLAHUAC
# 370                  TLAHUAC
# 371                IZTACALCO
# 372                IZTACALCO
# 373                IZTACALCO
# 374                IZTACALCO
# 375                IZTACALCO
# 376                IZTACALCO
# 377             AZCAPOTZALCO
# 378             AZCAPOTZALCO
# 379             AZCAPOTZALCO
# 380             AZCAPOTZALCO
# 381             AZCAPOTZALCO
# 382           ALVARO OBREGON
# 383           ALVARO OBREGON
# 384           ALVARO OBREGON
# 385           ALVARO OBREGON
# 386           ALVARO OBREGON
# 387           ALVARO OBREGON
# 388           ALVARO OBREGON
# 389           ALVARO OBREGON
# 390           ALVARO OBREGON
# 391           ALVARO OBREGON
# 392           ALVARO OBREGON
# 393           ALVARO OBREGON
# 394               CUAUHTEMOC
# 395               CUAUHTEMOC
# 396               CUAUHTEMOC
# 397               CUAUHTEMOC
# 398        GUSTAVO A. MADERO
# 399        GUSTAVO A. MADERO
# 400        GUSTAVO A. MADERO
# 401        GUSTAVO A. MADERO
# 402               XOCHIMILCO
# 403                  TLALPAN
# 404                  TLALPAN
# 405                  TLALPAN
# 406                  TLALPAN
# 407                  TLALPAN
# 408                  TLALPAN
# 409                  TLALPAN
# 410                  TLALPAN
# 411                  TLALPAN
# 412                  TLALPAN
# 413               XOCHIMILCO
# 414                  TLALPAN
# 415        GUSTAVO A. MADERO
# 416        GUSTAVO A. MADERO
# 417        GUSTAVO A. MADERO
# 418        GUSTAVO A. MADERO
# 419        GUSTAVO A. MADERO
# 420        GUSTAVO A. MADERO
# 421        GUSTAVO A. MADERO
# 422    CUAJIMALPA DE MORELOS
# 423    CUAJIMALPA DE MORELOS
# 424               IZTAPALAPA
# 425    CUAJIMALPA DE MORELOS
# 426   LA MAGDALENA CONTRERAS
# 427   LA MAGDALENA CONTRERAS
# 428   LA MAGDALENA CONTRERAS
# 429   LA MAGDALENA CONTRERAS
# 430   LA MAGDALENA CONTRERAS
# 431   LA MAGDALENA CONTRERAS
# 432            BENITO JUAREZ
# 433            BENITO JUAREZ
# 434               IZTAPALAPA
# 435               IZTAPALAPA
# 436               IZTAPALAPA
# 437               IZTAPALAPA
# 438               IZTAPALAPA
# 439               IZTAPALAPA
# 440               IZTAPALAPA
# 441               IZTAPALAPA
# 442               IZTAPALAPA
# 443               IZTAPALAPA
# 444               IZTAPALAPA
# 445               IZTAPALAPA
# 446               IZTAPALAPA
# 447               IZTAPALAPA
# 448               CUAUHTEMOC
# 449               IZTAPALAPA
# 450               IZTAPALAPA
# 451           MIGUEL HIDALGO
# 452           MIGUEL HIDALGO
# 453           MIGUEL HIDALGO
# 454           MIGUEL HIDALGO
# 455           MIGUEL HIDALGO
# 456                 COYOACAN
# 457                 COYOACAN
# 458                 COYOACAN
# 459                 COYOACAN
# 460                 COYOACAN
# 461                 COYOACAN
# 462                 COYOACAN
# 463                 COYOACAN
# 464                 COYOACAN
# 465                 COYOACAN
# 466      VENUSTIANO CARRANZA
# 467      VENUSTIANO CARRANZA
# 468      VENUSTIANO CARRANZA
# 469            BENITO JUAREZ
# 470            BENITO JUAREZ
# 471            BENITO JUAREZ
# 472            BENITO JUAREZ
# 473            BENITO JUAREZ
# 474        GUSTAVO A. MADERO
# 475        GUSTAVO A. MADERO
# 476        GUSTAVO A. MADERO
# 477        GUSTAVO A. MADERO
# 478        GUSTAVO A. MADERO
# 479        GUSTAVO A. MADERO
# 480        GUSTAVO A. MADERO
# 481        GUSTAVO A. MADERO
# 482        GUSTAVO A. MADERO
# 483        GUSTAVO A. MADERO
# 484        GUSTAVO A. MADERO
# 485        GUSTAVO A. MADERO
# 486        GUSTAVO A. MADERO
# 487        GUSTAVO A. MADERO
# 488        GUSTAVO A. MADERO
# 489        GUSTAVO A. MADERO
# 490               MILPA ALTA
# 491        GUSTAVO A. MADERO
# 492        GUSTAVO A. MADERO
# 493                  TLALPAN
# 494                  TLALPAN
# 495                  TLALPAN
# 496                  TLALPAN
# 497        GUSTAVO A. MADERO
# 498        GUSTAVO A. MADERO
# 499        GUSTAVO A. MADERO
# 500        GUSTAVO A. MADERO
# 501                  TLALPAN
# 502                  TLALPAN
# 503                  TLALPAN
# 504                  TLALPAN
# 505                  TLALPAN
# 506                  TLALPAN
# 507               XOCHIMILCO
# 508               XOCHIMILCO
# 509               XOCHIMILCO
# 510               XOCHIMILCO
# 511               XOCHIMILCO
# 512               XOCHIMILCO
# 513               XOCHIMILCO
# 514                  TLAHUAC
# 515                  TLAHUAC
# 516                  TLAHUAC
# 517                  TLAHUAC
# 518                  TLAHUAC
# 519             AZCAPOTZALCO
# 520           ALVARO OBREGON
# 521           ALVARO OBREGON
# 522           ALVARO OBREGON
# 523           ALVARO OBREGON
# 524           ALVARO OBREGON
# 525           ALVARO OBREGON
# 526           ALVARO OBREGON
# 527           ALVARO OBREGON
# 528           ALVARO OBREGON
# 529           ALVARO OBREGON
# 530           ALVARO OBREGON
# 531           ALVARO OBREGON
# 532           ALVARO OBREGON
# 533           ALVARO OBREGON
# 534           ALVARO OBREGON
# 535           ALVARO OBREGON
# 536               CUAUHTEMOC
# 537           ALVARO OBREGON
# 538           ALVARO OBREGON
# 539           ALVARO OBREGON
# 540           ALVARO OBREGON
# 541           ALVARO OBREGON
# 542                IZTACALCO
# 543                IZTACALCO
# 544                IZTACALCO
# 545                IZTACALCO
# 546                IZTACALCO
# 547             AZCAPOTZALCO
# 548             AZCAPOTZALCO
# 549             AZCAPOTZALCO
# 550             AZCAPOTZALCO
# 551             AZCAPOTZALCO
# 552             AZCAPOTZALCO
# 553             AZCAPOTZALCO
# 554               CUAUHTEMOC
# 555               CUAUHTEMOC
# 556               CUAUHTEMOC
# 557               CUAUHTEMOC
# 558               IZTAPALAPA
# 559               IZTAPALAPA
# 560               IZTAPALAPA
# 561               IZTAPALAPA
# 562               IZTAPALAPA
# 563               IZTAPALAPA
# 564               IZTAPALAPA
# 565               IZTAPALAPA
# 566               IZTAPALAPA
# 567               IZTAPALAPA
# 568               IZTAPALAPA
# 569               IZTAPALAPA
# 570               IZTAPALAPA
# 571               IZTAPALAPA
# 572               IZTAPALAPA
# 573               IZTAPALAPA
# 574               IZTAPALAPA
# 575            BENITO JUAREZ
# 576            BENITO JUAREZ
# 577    CUAJIMALPA DE MORELOS
# 578   LA MAGDALENA CONTRERAS
# 579    CUAJIMALPA DE MORELOS
# 580    CUAJIMALPA DE MORELOS
# 581    CUAJIMALPA DE MORELOS
# 582   LA MAGDALENA CONTRERAS
# 583            BENITO JUAREZ
# 584            BENITO JUAREZ
# 585               IZTAPALAPA
# 586               IZTAPALAPA
# 587               IZTAPALAPA
# 588               IZTAPALAPA
# 589               IZTAPALAPA
# 590               IZTAPALAPA
# 591               IZTAPALAPA
# 592           MIGUEL HIDALGO
# 593           MIGUEL HIDALGO
# 594           MIGUEL HIDALGO
# 595           MIGUEL HIDALGO
# 596           MIGUEL HIDALGO
# 597           MIGUEL HIDALGO
# 598           MIGUEL HIDALGO
# 599      VENUSTIANO CARRANZA
# 600      VENUSTIANO CARRANZA
# 601      VENUSTIANO CARRANZA
# 602                 COYOACAN
# 603           MIGUEL HIDALGO
# 604           MIGUEL HIDALGO
# 605                 COYOACAN
# 606                 COYOACAN
# 607                 COYOACAN
# 608                 COYOACAN
# 609                 COYOACAN
# 610                 COYOACAN
# 611                 COYOACAN
# 612                 COYOACAN
# 613      VENUSTIANO CARRANZA
# 614                 COYOACAN
# 615                 COYOACAN
# 616      VENUSTIANO CARRANZA
# 617           MIGUEL HIDALGO
# 618           MIGUEL HIDALGO
# 619           MIGUEL HIDALGO
# 620                 COYOACAN
# 621                 COYOACAN
# 622                 COYOACAN
# 623      VENUSTIANO CARRANZA
# 624      VENUSTIANO CARRANZA
# 625      VENUSTIANO CARRANZA
# 626      VENUSTIANO CARRANZA
# 627      VENUSTIANO CARRANZA
# 628           MIGUEL HIDALGO
# 629           MIGUEL HIDALGO
# 630                 COYOACAN
# 631      VENUSTIANO CARRANZA
# 632      VENUSTIANO CARRANZA
# 633      VENUSTIANO CARRANZA
# 634      VENUSTIANO CARRANZA
# 635      VENUSTIANO CARRANZA
# 636                 COYOACAN
# 637                 COYOACAN
# 638                 COYOACAN
# 639                 COYOACAN
# 640                 COYOACAN
# 641        GUSTAVO A. MADERO
# 642        GUSTAVO A. MADERO
# 643        GUSTAVO A. MADERO
# 644        GUSTAVO A. MADERO
# 645        GUSTAVO A. MADERO
# 646        GUSTAVO A. MADERO
# 647        GUSTAVO A. MADERO
# 648        GUSTAVO A. MADERO
# 649        GUSTAVO A. MADERO
# 650        GUSTAVO A. MADERO
# 651        GUSTAVO A. MADERO
# 652        GUSTAVO A. MADERO
# 653        GUSTAVO A. MADERO
# 654        GUSTAVO A. MADERO
# 655                  TLALPAN
# 656                  TLALPAN
# 657                  TLALPAN
# 658                  TLALPAN
# 659                  TLALPAN
# 660                  TLALPAN
# 661                  TLALPAN
# 662                  TLALPAN
# 663               XOCHIMILCO
# 664               XOCHIMILCO
# 665                  TLALPAN
# 666                  TLALPAN
# 667               MILPA ALTA
# 668        GUSTAVO A. MADERO
# 669        GUSTAVO A. MADERO
# 670                  TLALPAN
# 671                  TLALPAN
# 672                  TLALPAN
# 673               XOCHIMILCO
# 674                  TLALPAN
# 675                  TLALPAN
# 676                  TLALPAN
# 677                  TLALPAN
# 678                  TLALPAN
# 679                IZTACALCO
# 680                IZTACALCO
# 681             AZCAPOTZALCO
# 682             AZCAPOTZALCO
# 683             AZCAPOTZALCO
# 684             AZCAPOTZALCO
# 685           ALVARO OBREGON
# 686           ALVARO OBREGON
# 687           ALVARO OBREGON
# 688               CUAUHTEMOC
# 689           ALVARO OBREGON
# 690                  TLAHUAC
# 691                  TLAHUAC
# 692             AZCAPOTZALCO
# 693                  TLAHUAC
# 694           ALVARO OBREGON
# 695           ALVARO OBREGON
# 696           ALVARO OBREGON
# 697           ALVARO OBREGON
# 698           ALVARO OBREGON
# 699           ALVARO OBREGON
# 700           ALVARO OBREGON
# 701           ALVARO OBREGON
# 702           ALVARO OBREGON
# 703           ALVARO OBREGON
# 704                IZTACALCO
# 705                  TLAHUAC
# 706                  TLAHUAC
# 707                IZTACALCO
# 708           ALVARO OBREGON
# 709           ALVARO OBREGON
# 710           ALVARO OBREGON
# 711           ALVARO OBREGON
# 712               CUAUHTEMOC
# 713    CUAJIMALPA DE MORELOS
# 714               IZTAPALAPA
# 715               IZTAPALAPA
# 716               IZTAPALAPA
# 717               IZTAPALAPA
# 718               IZTAPALAPA
# 719               IZTAPALAPA
# 720               IZTAPALAPA
# 721               IZTAPALAPA
# 722               IZTAPALAPA
# 723               IZTAPALAPA
# 724               IZTAPALAPA
# 725               IZTAPALAPA
# 726               IZTAPALAPA
# 727               IZTAPALAPA
# 728               IZTAPALAPA
# 729               IZTAPALAPA
# 730            BENITO JUAREZ
# 731            BENITO JUAREZ
# 732            BENITO JUAREZ
# 733    CUAJIMALPA DE MORELOS
# 734    CUAJIMALPA DE MORELOS
# 735    CUAJIMALPA DE MORELOS
# 736    CUAJIMALPA DE MORELOS
# 737   LA MAGDALENA CONTRERAS
# 738            BENITO JUAREZ
# 739               IZTAPALAPA
# 740               IZTAPALAPA
# 741               IZTAPALAPA
# 742               IZTAPALAPA
# 743            BENITO JUAREZ
# 744            BENITO JUAREZ
# 745               CUAUHTEMOC
# 746               CUAUHTEMOC
# 747           MIGUEL HIDALGO
# 748        GUSTAVO A. MADERO
# 749        GUSTAVO A. MADERO
# 750             AZCAPOTZALCO
# 751             AZCAPOTZALCO
# 752             AZCAPOTZALCO
# 753             AZCAPOTZALCO
# 754               MILPA ALTA
# 755                  TLALPAN
# 756                  TLALPAN
# 757                  TLALPAN
# 758        GUSTAVO A. MADERO
# 759        GUSTAVO A. MADERO
# 760        GUSTAVO A. MADERO
# 761        GUSTAVO A. MADERO
# 762        GUSTAVO A. MADERO
# 763        GUSTAVO A. MADERO
# 764        GUSTAVO A. MADERO
# 765        GUSTAVO A. MADERO
# 766        GUSTAVO A. MADERO
# 767        GUSTAVO A. MADERO
# 768               XOCHIMILCO
# 769               XOCHIMILCO
# 770               XOCHIMILCO
# 771               XOCHIMILCO
# 772               XOCHIMILCO
# 773               XOCHIMILCO
# 774               XOCHIMILCO
# 775                  TLALPAN
# 776                  TLALPAN
# 777                  TLALPAN
# 778                  TLALPAN
# 779                  TLALPAN
# 780               XOCHIMILCO
# 781               XOCHIMILCO
# 782        GUSTAVO A. MADERO
# 783        GUSTAVO A. MADERO
# 784        GUSTAVO A. MADERO
# 785        GUSTAVO A. MADERO
# 786                  TLALPAN
# 787                  TLALPAN
# 788                  TLALPAN
# 789                  TLALPAN
# 790                IZTACALCO
# 791             AZCAPOTZALCO
# 792                  TLAHUAC
# 793                  TLAHUAC
# 794                IZTACALCO
# 795                IZTACALCO
# 796                IZTACALCO
# 797                IZTACALCO
# 798                IZTACALCO
# 799           ALVARO OBREGON
# 800             AZCAPOTZALCO
# 801             AZCAPOTZALCO
# 802             AZCAPOTZALCO
# 803           ALVARO OBREGON
# 804           ALVARO OBREGON
# 805           ALVARO OBREGON
# 806           ALVARO OBREGON
# 807           ALVARO OBREGON
# 808           ALVARO OBREGON
# 809           ALVARO OBREGON
# 810           ALVARO OBREGON
# 811           ALVARO OBREGON
# 812           ALVARO OBREGON
# 813           ALVARO OBREGON
# 814           ALVARO OBREGON
# 815           ALVARO OBREGON
# 816           ALVARO OBREGON
# 817           ALVARO OBREGON
# 818               IZTAPALAPA
# 819               IZTAPALAPA
# 820               IZTAPALAPA
# 821               IZTAPALAPA
# 822               IZTAPALAPA
# 823               IZTAPALAPA
# 824               IZTAPALAPA
# 825               IZTAPALAPA
# 826               IZTAPALAPA
# 827               IZTAPALAPA
# 828               IZTAPALAPA
# 829               IZTAPALAPA
# 830               IZTAPALAPA
# 831               IZTAPALAPA
# 832               IZTAPALAPA
# 833               IZTAPALAPA
# 834               IZTAPALAPA
# 835               IZTAPALAPA
# 836               IZTAPALAPA
# 837               IZTAPALAPA
# 838               IZTAPALAPA
# 839               IZTAPALAPA
# 840               IZTAPALAPA
# 841   LA MAGDALENA CONTRERAS
# 842   LA MAGDALENA CONTRERAS
# 843   LA MAGDALENA CONTRERAS
# 844   LA MAGDALENA CONTRERAS
# 845   LA MAGDALENA CONTRERAS
# 846   LA MAGDALENA CONTRERAS
# 847   LA MAGDALENA CONTRERAS
# 848            BENITO JUAREZ
# 849           MIGUEL HIDALGO
# 850           MIGUEL HIDALGO
# 851           MIGUEL HIDALGO
# 852           MIGUEL HIDALGO
# 853           MIGUEL HIDALGO
# 854                 COYOACAN
# 855                 COYOACAN
# 856                 COYOACAN
# 857                 COYOACAN
# 858                 COYOACAN
# 859                 COYOACAN
# 860                 COYOACAN
# 861                 COYOACAN
# 862                 COYOACAN
# 863      VENUSTIANO CARRANZA
# 864      VENUSTIANO CARRANZA
# 865      VENUSTIANO CARRANZA
# 866      VENUSTIANO CARRANZA
# 867      VENUSTIANO CARRANZA
# 868      VENUSTIANO CARRANZA
# 869      VENUSTIANO CARRANZA
# 870        GUSTAVO A. MADERO
# 871        GUSTAVO A. MADERO
# 872        GUSTAVO A. MADERO
# 873        GUSTAVO A. MADERO
# 874        GUSTAVO A. MADERO
# 875        GUSTAVO A. MADERO
# 876               XOCHIMILCO
# 877               XOCHIMILCO
# 878               MILPA ALTA
# 879        GUSTAVO A. MADERO
# 880        GUSTAVO A. MADERO
# 881        GUSTAVO A. MADERO
# 882               XOCHIMILCO
# 883                  TLALPAN
# 884                  TLALPAN
# 885                  TLALPAN
# 886                  TLALPAN
# 887                  TLALPAN
# 888                  TLALPAN
# 889                  TLALPAN
# 890                  TLALPAN
# 891                  TLALPAN
# 892        GUSTAVO A. MADERO
# 893        GUSTAVO A. MADERO
# 894        GUSTAVO A. MADERO
# 895        GUSTAVO A. MADERO
# 896                  TLALPAN
# 897                  TLALPAN
# 898                  TLALPAN
# 899                  TLALPAN
# 900                  TLAHUAC
# 901                  TLAHUAC
# 902                  TLAHUAC
# 903                  TLAHUAC
# 904           ALVARO OBREGON
# 905             AZCAPOTZALCO
# 906           ALVARO OBREGON
# 907             AZCAPOTZALCO
# 908             AZCAPOTZALCO
# 909             AZCAPOTZALCO
# 910             AZCAPOTZALCO
# 911             AZCAPOTZALCO
# 912             AZCAPOTZALCO
# 913                  TLAHUAC
# 914                  TLAHUAC
# 915             AZCAPOTZALCO
# 916               CUAUHTEMOC
# 917               CUAUHTEMOC
# 918           ALVARO OBREGON
# 919           ALVARO OBREGON
# 920           ALVARO OBREGON
# 921           ALVARO OBREGON
# 922           ALVARO OBREGON
# 923           ALVARO OBREGON
# 924           ALVARO OBREGON
# 925           ALVARO OBREGON
# 926           ALVARO OBREGON
# 927           ALVARO OBREGON
# 928           ALVARO OBREGON
# 929           ALVARO OBREGON
# 930           ALVARO OBREGON
# 931           ALVARO OBREGON
# 932           ALVARO OBREGON
# 933                IZTACALCO
# 934                IZTACALCO
# 935               CUAUHTEMOC
# 936               CUAUHTEMOC
# 937               CUAUHTEMOC
# 938               CUAUHTEMOC
# 939               CUAUHTEMOC
# 940                 COYOACAN
# 941           MIGUEL HIDALGO
# 942           MIGUEL HIDALGO
# 943           MIGUEL HIDALGO
# 944           MIGUEL HIDALGO
# 945    CUAJIMALPA DE MORELOS
# 946    CUAJIMALPA DE MORELOS
# 947               IZTAPALAPA
# 948               IZTAPALAPA
# 949               IZTAPALAPA
# 950               IZTAPALAPA
# 951               IZTAPALAPA
# 952               IZTAPALAPA
# 953               IZTAPALAPA
# 954               IZTAPALAPA
# 955               IZTAPALAPA
# 956               IZTAPALAPA
# 957               IZTAPALAPA
# 958               IZTAPALAPA
# 959               IZTAPALAPA
# 960               IZTAPALAPA
# 961               IZTAPALAPA
# 962               IZTAPALAPA
# 963               IZTAPALAPA
# 964           MIGUEL HIDALGO
# 965            BENITO JUAREZ
# 966           MIGUEL HIDALGO
# 967           MIGUEL HIDALGO
# 968   LA MAGDALENA CONTRERAS
# 969   LA MAGDALENA CONTRERAS
# 970   LA MAGDALENA CONTRERAS
# 971               IZTAPALAPA
# 972               IZTAPALAPA
# 973               IZTAPALAPA
# 974               IZTAPALAPA
# 975            BENITO JUAREZ
# 976            BENITO JUAREZ
# 977           MIGUEL HIDALGO
# 978           MIGUEL HIDALGO
# 979           MIGUEL HIDALGO
# 980                 COYOACAN
# 981                 COYOACAN
# 982                 COYOACAN
# 983                 COYOACAN
# 984                 COYOACAN
# 985                 COYOACAN
# 986      VENUSTIANO CARRANZA
# 987      VENUSTIANO CARRANZA
# 988      VENUSTIANO CARRANZA
# 989      VENUSTIANO CARRANZA
# 990      VENUSTIANO CARRANZA
# 991                 COYOACAN
# 992                 COYOACAN
# 993                 COYOACAN
# 994           ALVARO OBREGON
# 995           ALVARO OBREGON
# 996           ALVARO OBREGON
# 997           ALVARO OBREGON
# 998                  TLAHUAC
# 999                  TLAHUAC
# 1000            AZCAPOTZALCO
# 1001            AZCAPOTZALCO
# 1002            AZCAPOTZALCO
# 1003            AZCAPOTZALCO
# 1004            AZCAPOTZALCO
# 1005            AZCAPOTZALCO
# 1006            AZCAPOTZALCO
# 1007            AZCAPOTZALCO
# 1008            AZCAPOTZALCO
# 1009            AZCAPOTZALCO
# 1010            AZCAPOTZALCO
# 1011          ALVARO OBREGON
# 1012          ALVARO OBREGON
# 1013          ALVARO OBREGON
# 1014          ALVARO OBREGON
# 1015          ALVARO OBREGON
# 1016          ALVARO OBREGON
# 1017          ALVARO OBREGON
# 1018          ALVARO OBREGON
# 1019          ALVARO OBREGON
# 1020          ALVARO OBREGON
# 1021          ALVARO OBREGON
# 1022          ALVARO OBREGON
# 1023          ALVARO OBREGON
# 1024          ALVARO OBREGON
# 1025          ALVARO OBREGON
# 1026          ALVARO OBREGON
# 1027          ALVARO OBREGON
# 1028          ALVARO OBREGON
# 1029          ALVARO OBREGON
# 1030          ALVARO OBREGON
# 1031              CUAUHTEMOC
# 1032          ALVARO OBREGON
# 1033          ALVARO OBREGON
# 1034          ALVARO OBREGON
# 1035          ALVARO OBREGON
# 1036              CUAUHTEMOC
# 1037              CUAUHTEMOC
# 1038       GUSTAVO A. MADERO
# 1039       GUSTAVO A. MADERO
# 1040       GUSTAVO A. MADERO
# 1041       GUSTAVO A. MADERO
# 1042              XOCHIMILCO
# 1043              XOCHIMILCO
# 1044              XOCHIMILCO
# 1045              XOCHIMILCO
# 1046                 TLALPAN
# 1047                 TLALPAN
# 1048                 TLALPAN
# 1049                 TLALPAN
# 1050                 TLALPAN
# 1051                 TLALPAN
# 1052                 TLALPAN
# 1053                 TLALPAN
# 1054                 TLALPAN
# 1055       GUSTAVO A. MADERO
# 1056       GUSTAVO A. MADERO
# 1057       GUSTAVO A. MADERO
# 1058       GUSTAVO A. MADERO
# 1059       GUSTAVO A. MADERO
# 1060                 TLALPAN
# 1061       GUSTAVO A. MADERO
# 1062       GUSTAVO A. MADERO
# 1063       GUSTAVO A. MADERO
# 1064              XOCHIMILCO
# 1065   CUAJIMALPA DE MORELOS
# 1066              IZTAPALAPA
# 1067              IZTAPALAPA
# 1068   CUAJIMALPA DE MORELOS
# 1069   CUAJIMALPA DE MORELOS
# 1070  LA MAGDALENA CONTRERAS
# 1071  LA MAGDALENA CONTRERAS
# 1072  LA MAGDALENA CONTRERAS
# 1073  LA MAGDALENA CONTRERAS
# 1074           BENITO JUAREZ
# 1075           BENITO JUAREZ
# 1076              IZTAPALAPA
# 1077              IZTAPALAPA
# 1078              IZTAPALAPA
# 1079              IZTAPALAPA
# 1080              IZTAPALAPA
# 1081              IZTAPALAPA
# 1082              IZTAPALAPA
# 1083              IZTAPALAPA
# 1084              IZTAPALAPA
# 1085              IZTAPALAPA
# 1086              IZTAPALAPA
# 1087              IZTAPALAPA
# 1088              IZTAPALAPA
# 1089              IZTAPALAPA
# 1090              IZTAPALAPA
# 1091              IZTAPALAPA
# 1092              IZTAPALAPA
# 1093              IZTAPALAPA
# 1094          MIGUEL HIDALGO
# 1095          MIGUEL HIDALGO
# 1096          MIGUEL HIDALGO
# 1097          MIGUEL HIDALGO
# 1098          MIGUEL HIDALGO
# 1099          MIGUEL HIDALGO
# 1100          MIGUEL HIDALGO
# 1101          MIGUEL HIDALGO
# 1102                COYOACAN
# 1103                COYOACAN
# 1104                COYOACAN
# 1105                COYOACAN
# 1106                COYOACAN
# 1107                COYOACAN
# 1108                COYOACAN
# 1109                COYOACAN
# 1110                COYOACAN
# 1111                COYOACAN
# 1112                COYOACAN
# 1113     VENUSTIANO CARRANZA
# 1114     VENUSTIANO CARRANZA
# 1115           BENITO JUAREZ
# 1116       GUSTAVO A. MADERO
# 1117       GUSTAVO A. MADERO
# 1118       GUSTAVO A. MADERO
# 1119       GUSTAVO A. MADERO
# 1120       GUSTAVO A. MADERO
# 1121       GUSTAVO A. MADERO
# 1122              MILPA ALTA
# 1123              MILPA ALTA
# 1124       GUSTAVO A. MADERO
# 1125                 TLALPAN
# 1126                 TLALPAN
# 1127                 TLALPAN
# 1128       GUSTAVO A. MADERO
# 1129       GUSTAVO A. MADERO
# 1130                 TLALPAN
# 1131                 TLALPAN
# 1132                 TLALPAN
# 1133                 TLALPAN
# 1134                 TLALPAN
# 1135                 TLALPAN
# 1136                 TLALPAN
# 1137                 TLALPAN
# 1138              XOCHIMILCO
# 1139              XOCHIMILCO
# 1140              XOCHIMILCO
# 1141              XOCHIMILCO
# 1142              XOCHIMILCO
# 1143                 TLAHUAC
# 1144                 TLAHUAC
# 1145                 TLAHUAC
# 1146                 TLAHUAC
# 1147            AZCAPOTZALCO
# 1148            AZCAPOTZALCO
# 1149                 TLAHUAC
# 1150                 TLAHUAC
# 1151            AZCAPOTZALCO
# 1152          ALVARO OBREGON
# 1153          ALVARO OBREGON
# 1154          ALVARO OBREGON
# 1155          ALVARO OBREGON
# 1156          ALVARO OBREGON
# 1157          ALVARO OBREGON
# 1158          ALVARO OBREGON
# 1159              CUAUHTEMOC
# 1160              CUAUHTEMOC
# 1161          ALVARO OBREGON
# 1162              CUAUHTEMOC
# 1163          ALVARO OBREGON
# 1164          ALVARO OBREGON
# 1165               IZTACALCO
# 1166               IZTACALCO
# 1167               IZTACALCO
# 1168          ALVARO OBREGON
# 1169            AZCAPOTZALCO
# 1170          ALVARO OBREGON
# 1171              CUAUHTEMOC
# 1172              CUAUHTEMOC
# 1173              CUAUHTEMOC
# 1174              CUAUHTEMOC
# 1175   CUAJIMALPA DE MORELOS
# 1176              IZTAPALAPA
# 1177              IZTAPALAPA
# 1178              IZTAPALAPA
# 1179              IZTAPALAPA
# 1180              IZTAPALAPA
# 1181              IZTAPALAPA
# 1182              IZTAPALAPA
# 1183              IZTAPALAPA
# 1184              IZTAPALAPA
# 1185              IZTAPALAPA
# 1186           BENITO JUAREZ
# 1187          MIGUEL HIDALGO
# 1188           BENITO JUAREZ
# 1189   CUAJIMALPA DE MORELOS
# 1190   CUAJIMALPA DE MORELOS
# 1191  LA MAGDALENA CONTRERAS
# 1192   CUAJIMALPA DE MORELOS
# 1193  LA MAGDALENA CONTRERAS
# 1194           BENITO JUAREZ
# 1195           BENITO JUAREZ
# 1196              IZTAPALAPA
# 1197              IZTAPALAPA
# 1198              CUAUHTEMOC
# 1199              CUAUHTEMOC
# 1200              CUAUHTEMOC
# 1201              CUAUHTEMOC
# 1202              IZTAPALAPA
# 1203          MIGUEL HIDALGO
# 1204          MIGUEL HIDALGO
# 1205          MIGUEL HIDALGO
# 1206          MIGUEL HIDALGO
# 1207          MIGUEL HIDALGO
# 1208          MIGUEL HIDALGO
# 1209     VENUSTIANO CARRANZA
# 1210     VENUSTIANO CARRANZA
# 1211                COYOACAN
# 1212                COYOACAN
# 1213                COYOACAN
# 1214                COYOACAN
# 1215                COYOACAN
# 1216                COYOACAN
# 1217                COYOACAN
# 1218                COYOACAN
# 1219                COYOACAN
# 1220                COYOACAN
# 1221                COYOACAN
# 1222     VENUSTIANO CARRANZA
# 1223          MIGUEL HIDALGO
# 1224          MIGUEL HIDALGO
# 1225                COYOACAN
# 1226                COYOACAN
# 1227                COYOACAN
# 1228     VENUSTIANO CARRANZA
# 1229     VENUSTIANO CARRANZA
# 1230                COYOACAN
# 1231          MIGUEL HIDALGO
# 1232                COYOACAN
# 1233                COYOACAN
# 1234     VENUSTIANO CARRANZA
# 1235     VENUSTIANO CARRANZA
# 1236                COYOACAN
# 1237                COYOACAN
# 1238                COYOACAN
# 1239                COYOACAN
# 1240                COYOACAN
# 1241       GUSTAVO A. MADERO
# 1242       GUSTAVO A. MADERO
# 1243       GUSTAVO A. MADERO
# 1244       GUSTAVO A. MADERO
# 1245       GUSTAVO A. MADERO
# 1246       GUSTAVO A. MADERO
# 1247       GUSTAVO A. MADERO
# 1248       GUSTAVO A. MADERO
# 1249       GUSTAVO A. MADERO
# 1250       GUSTAVO A. MADERO
# 1251       GUSTAVO A. MADERO
# 1252       GUSTAVO A. MADERO
# 1253       GUSTAVO A. MADERO
# 1254       GUSTAVO A. MADERO
# 1255       GUSTAVO A. MADERO
# 1256       GUSTAVO A. MADERO
# 1257                 TLALPAN
# 1258                 TLALPAN
# 1259                 TLALPAN
# 1260                 TLALPAN
# 1261                 TLALPAN
# 1262                 TLALPAN
# 1263                 TLALPAN
# 1264              XOCHIMILCO
# 1265                 TLALPAN
# 1266                 TLALPAN
# 1267              MILPA ALTA
# 1268              MILPA ALTA
# 1269       GUSTAVO A. MADERO
# 1270                 TLALPAN
# 1271              XOCHIMILCO
# 1272              XOCHIMILCO
# 1273                 TLALPAN
# 1274                 TLALPAN
# 1275               IZTACALCO
# 1276            AZCAPOTZALCO
# 1277            AZCAPOTZALCO
# 1278            AZCAPOTZALCO
# 1279            AZCAPOTZALCO
# 1280            AZCAPOTZALCO
# 1281              CUAUHTEMOC
# 1282              CUAUHTEMOC
# 1283                 TLAHUAC
# 1284                 TLAHUAC
# 1285            AZCAPOTZALCO
# 1286          ALVARO OBREGON
# 1287          ALVARO OBREGON
# 1288          ALVARO OBREGON
# 1289          ALVARO OBREGON
# 1290          ALVARO OBREGON
# 1291          ALVARO OBREGON
# 1292            AZCAPOTZALCO
# 1293          ALVARO OBREGON
# 1294          ALVARO OBREGON
# 1295               IZTACALCO
# 1296               IZTACALCO
# 1297               IZTACALCO
# 1298          ALVARO OBREGON
# 1299          ALVARO OBREGON
# 1300          ALVARO OBREGON
# 1301          ALVARO OBREGON
# 1302              CUAUHTEMOC
# 1303              IZTAPALAPA
# 1304              IZTAPALAPA
# 1305              IZTAPALAPA
# 1306              IZTAPALAPA
# 1307              IZTAPALAPA
# 1308              IZTAPALAPA
# 1309              IZTAPALAPA
# 1310              IZTAPALAPA
# 1311              IZTAPALAPA
# 1312              IZTAPALAPA
# 1313              IZTAPALAPA
# 1314              IZTAPALAPA
# 1315              IZTAPALAPA
# 1316              IZTAPALAPA
# 1317              IZTAPALAPA
# 1318          MIGUEL HIDALGO
# 1319   CUAJIMALPA DE MORELOS
# 1320   CUAJIMALPA DE MORELOS
# 1321   CUAJIMALPA DE MORELOS
# 1322   CUAJIMALPA DE MORELOS
# 1323  LA MAGDALENA CONTRERAS
# 1324  LA MAGDALENA CONTRERAS
# 1325  LA MAGDALENA CONTRERAS
# 1326  LA MAGDALENA CONTRERAS
# 1327              IZTAPALAPA
# 1328              IZTAPALAPA
# 1329              IZTAPALAPA
# 1330           BENITO JUAREZ
# 1331           BENITO JUAREZ
# 1332           BENITO JUAREZ
# 1333           BENITO JUAREZ
# 1334              IZTAPALAPA
# 1335              CUAUHTEMOC
# 1336              IZTAPALAPA
# 1337              CUAUHTEMOC
# 1338          MIGUEL HIDALGO
# 1339       GUSTAVO A. MADERO
# 1340       GUSTAVO A. MADERO
# 1341            AZCAPOTZALCO
# 1342            AZCAPOTZALCO
# 1343                 TLALPAN
# 1344                 TLALPAN
# 1345                 TLALPAN
# 1346                 TLALPAN
# 1347       GUSTAVO A. MADERO
# 1348       GUSTAVO A. MADERO
# 1349       GUSTAVO A. MADERO
# 1350       GUSTAVO A. MADERO
# 1351       GUSTAVO A. MADERO
# 1352       GUSTAVO A. MADERO
# 1353       GUSTAVO A. MADERO
# 1354       GUSTAVO A. MADERO
# 1355       GUSTAVO A. MADERO
# 1356              XOCHIMILCO
# 1357              XOCHIMILCO
# 1358              XOCHIMILCO
# 1359              XOCHIMILCO
# 1360                 TLALPAN
# 1361                 TLALPAN
# 1362                 TLALPAN
# 1363                 TLALPAN
# 1364                 TLALPAN
# 1365              XOCHIMILCO
# 1366                 TLALPAN
# 1367       GUSTAVO A. MADERO
# 1368       GUSTAVO A. MADERO
# 1369       GUSTAVO A. MADERO
# 1370                 TLALPAN
# 1371                 TLALPAN
# 1372                 TLALPAN
# 1373                 TLALPAN
# 1374               IZTACALCO
# 1375               IZTACALCO
# 1376          ALVARO OBREGON
# 1377          ALVARO OBREGON
# 1378            AZCAPOTZALCO
# 1379            AZCAPOTZALCO
# 1380            AZCAPOTZALCO
# 1381                 TLAHUAC
# 1382                 TLAHUAC
# 1383                 TLAHUAC
# 1384               IZTACALCO
# 1385               IZTACALCO
# 1386               IZTACALCO
# 1387          ALVARO OBREGON
# 1388          ALVARO OBREGON
# 1389          ALVARO OBREGON
# 1390          ALVARO OBREGON
# 1391          ALVARO OBREGON
# 1392          ALVARO OBREGON
# 1393            AZCAPOTZALCO
# 1394            AZCAPOTZALCO
# 1395            AZCAPOTZALCO
# 1396            AZCAPOTZALCO
# 1397            AZCAPOTZALCO
# 1398          ALVARO OBREGON
# 1399          ALVARO OBREGON
# 1400          ALVARO OBREGON
# 1401          ALVARO OBREGON
# 1402          ALVARO OBREGON
# 1403          ALVARO OBREGON
# 1404              CUAUHTEMOC
# 1405          ALVARO OBREGON
# 1406          ALVARO OBREGON
# 1407          ALVARO OBREGON
# 1408          ALVARO OBREGON
# 1409          ALVARO OBREGON
# 1410          ALVARO OBREGON
# 1411          ALVARO OBREGON
# 1412              IZTAPALAPA
# 1413              IZTAPALAPA
# 1414              IZTAPALAPA
# 1415              IZTAPALAPA
# 1416              IZTAPALAPA
# 1417              CUAUHTEMOC
# 1418              IZTAPALAPA
# 1419              IZTAPALAPA
# 1420              IZTAPALAPA
# 1421              IZTAPALAPA
# 1422              IZTAPALAPA
# 1423              IZTAPALAPA
# 1424              IZTAPALAPA
# 1425              IZTAPALAPA
# 1426              IZTAPALAPA
# 1427              IZTAPALAPA
# 1428              IZTAPALAPA
# 1429              IZTAPALAPA
# 1430              IZTAPALAPA
# 1431              IZTAPALAPA
# 1432              IZTAPALAPA
# 1433              IZTAPALAPA
# 1434              IZTAPALAPA
# 1435   CUAJIMALPA DE MORELOS
# 1436   CUAJIMALPA DE MORELOS
# 1437   CUAJIMALPA DE MORELOS
# 1438  LA MAGDALENA CONTRERAS
# 1439  LA MAGDALENA CONTRERAS
# 1440  LA MAGDALENA CONTRERAS
# 1441  LA MAGDALENA CONTRERAS
# 1442  LA MAGDALENA CONTRERAS
# 1443           BENITO JUAREZ
# 1444           BENITO JUAREZ
# 1445           BENITO JUAREZ
# 1446           BENITO JUAREZ
# 1447          MIGUEL HIDALGO
# 1448          MIGUEL HIDALGO
# 1449          MIGUEL HIDALGO
# 1450          MIGUEL HIDALGO
# 1451          MIGUEL HIDALGO
# 1452          MIGUEL HIDALGO
# 1453          MIGUEL HIDALGO
# 1454          MIGUEL HIDALGO
# 1455          MIGUEL HIDALGO
# 1456                COYOACAN
# 1457                COYOACAN
# 1458                COYOACAN
# 1459                COYOACAN
# 1460                COYOACAN
# 1461     VENUSTIANO CARRANZA
# 1462     VENUSTIANO CARRANZA
# 1463     VENUSTIANO CARRANZA
# 1464     VENUSTIANO CARRANZA
# 1465     VENUSTIANO CARRANZA
# 1466     VENUSTIANO CARRANZA
# 1467       GUSTAVO A. MADERO
# 1468       GUSTAVO A. MADERO
# 1469       GUSTAVO A. MADERO
# 1470       GUSTAVO A. MADERO
# 1471       GUSTAVO A. MADERO
# 1472       GUSTAVO A. MADERO
# 1473       GUSTAVO A. MADERO
# 1474       GUSTAVO A. MADERO
# 1475       GUSTAVO A. MADERO
# 1476       GUSTAVO A. MADERO
# 1477       GUSTAVO A. MADERO
# 1478       GUSTAVO A. MADERO
# 1479              XOCHIMILCO
# 1480              XOCHIMILCO
# 1481              XOCHIMILCO
# 1482       GUSTAVO A. MADERO
# 1483       GUSTAVO A. MADERO
# 1484       GUSTAVO A. MADERO
# 1485              XOCHIMILCO
# 1486              XOCHIMILCO
# 1487              XOCHIMILCO
# 1488              XOCHIMILCO
# 1489                 TLALPAN
# 1490                 TLALPAN
# 1491                 TLALPAN
# 1492                 TLALPAN
# 1493                 TLALPAN
# 1494                 TLALPAN
# 1495                 TLALPAN
# 1496                 TLALPAN
# 1497                 TLALPAN
# 1498                 TLALPAN
# ...
# 1612                             UNIDAD POPULAR TEPEACA  19.359155 -99.239662
# 1613                                2DA EL PIRUL (AMPL)  19.379750 -99.242101
# 1614                                         DEL OBRERO  19.500071 -99.091166
# 1615                                   SAN PEDRO (BARR)  19.256863 -99.108358
# 1616                      LA CONCEPCION TLACOAPA (BARR)  19.269084 -99.104508
# 1617                            SAN LORENZO LA CEBADA I  19.285070 -99.119101
# 1618                                     PASEOS DEL SUR  19.274925 -99.123882
# 1619                                    LOS CERRILLOS I        NaN        NaN
# 1620                    COLINAS DEL BOSQUE-LAS TORTOLAS  19.278218 -99.149444
# 1621                                            LA FAMA  19.290835 -99.176675
# 1622               EJIDOS DE SAN PEDRO MARTIR I (NORTE)  19.272094 -99.156965
# 1623                       PEDREGAL DE STA URSULA XITLA  19.273745 -99.178017
# 1624                       RANCHO LOS COLORINES (FRACC)  19.288185 -99.137777
# 1625                                    VALLE ESCONDIDO  19.277910 -99.144727
# 1626                                       CERRO GRANDE  19.238972 -99.117770
# 1627                                       BELEM (BARR)  19.260011 -99.102243
# 1628                                      TETENCO (PJE)  19.262929 -99.179518
# 1629                                          TLALPEXCO  19.546201 -99.126000
# 1630                     SAN BARTOLO ATEPEHUACAN (PBLO)  19.493597 -99.143365
# 1631                          SAN RAFAEL TICOMAN (BARR)  19.514404 -99.121826
# 1632                               ZONA ESCOLAR ORIENTE  19.539797 -99.142583
# 1633                                         6 DE JUNIO  19.550608 -99.125866
# 1634                      TORRES DE SAN JUAN 1B (U HAB)  19.480766 -99.092591
# 1635                             SAN FELIPE DE JESUS II  19.491708 -99.078302
# 1636                                PROGRESO NACIONAL I  19.520568 -99.161327
# 1637                                    LA ESMERALDA II  19.486015 -99.086059
# 1638                                        CHIMALCOYOC        NaN        NaN
# 1639                                        LA FORESTAL  19.562884 -99.131223
# 1640                       GERTRUDIS SANCHEZ 3A SECCION  19.461017 -99.101357
# 1641                                 GUADALUPE VICTORIA  19.539244 -99.140102
# 1642                                  INFONAVIT (U HAB)  19.516023 -99.141441
# 1643                                         INPI PICOS  19.387625 -99.103028
# 1644                             LOMAS DE SAN LORENZO I  19.315878 -99.057708
# 1645                   SANTA CRUZ MEYEHUALCO (U HAB) II  19.353062 -99.045225
# 1646                         ERMITA ZARAGOZA (U HAB) II  19.367009 -98.996967
# 1647                                         ZENTLAPATL  19.352747 -99.308252
# 1648                                      MANZANASTITLA  19.366436 -99.297711
# 1649                       SAN NICOLAS TOTOLAPAN (PBLO)  19.297057 -99.244844
# 1650                                       ATENOR SALAS  19.403145 -99.147862
# 1651                DESARROLLO URBANO QUETZALCOATL  III  19.323026 -99.040244
# 1652                                         RENOVACION  19.367389 -99.049440
# 1653                                    PARAJE SAN JUAN  19.341803 -99.071997
# 1654                        SAN JUAN 2A AMPLIACIN (PJE)  19.337774 -99.070102
# 1655                            SAN LORENZO 870 (U HAB)  19.332699 -99.074406
# 1656                                           PALMITAS  19.334886 -99.026134
# 1657                        LEYES DE REFORMA 2A SECCION  19.368351 -99.063196
# 1658                                       LA ESPERANZA  19.310478 -99.078468
# 1659                                             LA ERA  19.339721 -99.054662
# 1660                                         MODELO (U)  19.363875 -99.125289
# 1661                                     PARAISO (AMPL)  19.377493 -99.032472
# 1662                                         EL ROSARIO  19.301782 -99.065524
# 1663                                       JUSTO SIERRA  19.363721 -99.134838
# 1664                               CARLOS HANK GONZALEZ  19.331636 -99.047471
# 1665                        CUCHILLAS DEL MORAL (U HAB)  19.385180 -99.072676
# 1666                                        DEL VALLE V  19.375900 -99.168828
# 1667                                       MEXICO NUEVO  19.452450 -99.203913
# 1668                                          ANAHUAC I  19.447195 -99.175648
# 1669                CTM IX CULHUACAN ZONA 29-30 (U HAB)  19.313125 -99.102446
# 1670                            CTM V CULHUACAN (U HAB)  19.330986 -99.113493
# 1671                         JOYAS DEL PEDREGAL (FRACC)  19.305554 -99.157946
# 1672                                    LOS GIRASOLES I  19.304352 -99.120146
# 1673                                  LOS GIRASOLES III  19.307635 -99.126329
# 1674                                   LOS REYES (PBLO)  19.336146 -99.155349
# 1675                                  PETROLERA TAXQUEA  19.338492 -99.132692
# 1676                        VILLAS DEL PEDREGAL (U HAB)  19.304521 -99.174761
# 1677    ALIANZA POPULAR REVOLUCIONARIA PONIENTE (U HAB)  19.314310 -99.121987
# 1678                          PEDREGAL DE STO DOMINGO I  19.334758 -99.170774
# 1679                                    MONTE DE PIEDAD  19.343928 -99.173112
# 1680                EX EJIDO SAN FRANCISCO CULHUACAN II  19.330915 -99.126238
# 1681                               EL ARENAL 2A SECCION  19.423146 -99.056860
# 1682                                         MICHOACANA  19.446776 -99.114771
# 1683                               MOCTEZUMA 1A SECCION  19.428154 -99.106013
# 1684                                       PINO (U HAB)  19.409786 -99.098744
# 1685                                JARDIN BALBUENA III  19.413002 -99.104963
# 1686                            MOCTEZUMA 2A SECCION II  19.431452 -99.094256
# 1687                                PENSADOR MEXICANO I  19.445881 -99.081766
# 1688                            SAN PEDRO DE LOS  PINOS  19.390432 -99.184761
# 1689                                        NOCHE BUENA  19.380692 -99.178848
# 1690                                       DEL VALLE II  19.392396 -99.166932
# 1691                                          ALAMOS II  19.394901 -99.142231
# 1692                     ACUEDUCTO DE GUADALUPE (U HAB)  19.527166 -99.151137
# 1693                                      BENITO JUAREZ  19.532460 -99.139411
# 1694                           ARAGON LA VILLA (ARAGON)  19.479488 -99.113978
# 1695                                        CAPULTITLAN  19.478366 -99.133651
# 1696                                           EL OLIVO  19.473647 -99.086710
# 1697                                       EL ARBOLILLO  19.536200 -99.141091
# 1698       EJIDOS SAN JUAN DE ARAGON 1A SECCION (U HAB)  19.469125 -99.092570
# 1699                             EL ARBOLILLO 3 (U HAB)  19.537881 -99.144475
# 1700                               GUADALUPE PROLETARIA  19.521752 -99.155734
# 1701                     LA PATERA-CONDOMODULOS (U HAB)  19.503262 -99.153261
# 1702                               LA ESMERALDA (U HAB)  19.489385 -99.085291
# 1703                                 JAIME S EMILIANO G  19.547616 -99.134801
# 1704                                          MALACATES  19.574838 -99.134737
# 1705                                   MALACATES (AMPL)  19.581348 -99.126090
# 1706                                        SAN ANTONIO  19.560059 -99.137578
# 1707                     SAN SALVADOR CUAUHTENCO (PBLO)  19.191847 -99.094738
# 1708                                          VALLEJO I  19.467826 -99.135270
# 1709                                     MIGUEL HIDALGO  19.287727 -99.185750
# 1710                                     ORIENTE (AMPL)  19.252256 -99.161103
# 1711                               SOLIDARIDAD NACIONAL  19.534330 -99.153498
# 1712                          TORRES LINDAVISTA (FRACC)  19.510376 -99.144737
# 1713                          TORRES DE QUIROGA (U HAB)  19.490968 -99.095713
# 1714                                        25 DE JULIO  19.496012 -99.080976
# 1715                               SAN LORENZO HUIPULCO  19.295343 -99.149634
# 1716                                       LA MAGUEYERA  19.244465 -99.145813
# 1717                                 TORRES DE PADIERNA  19.281289 -99.228253
# 1718                                BELISARIO DOMINGUEZ  19.289504 -99.155586
# 1719                             SAN MATEO XALPA (PBLO)  19.230920 -99.120300
# 1720                                    SAN JOSE OBRERO  19.232887 -99.073935
# 1721                                 SAN JOSE ZACATEPEC  19.239124 -99.124212
# 1722                                 SAN LORENZO (BARR)  19.271900 -99.077526
# 1723                EJIDOS DE SAN PEDRO MARTIR II (SUR)  19.267447 -99.158872
# 1724                               SAN MIGUEL ZAPOTITLA  19.310620 -99.036815
# 1725                                           LA DRAGA  19.280316 -99.044720
# 1726             JARDINES DEL LLANO-U.H. VILLA TLATEMPA  19.230539 -98.988977
# 1727                                        OJO DE AGUA  19.289538 -99.012803
# 1728                               EL ROSARIO C (U HAB)  19.506158 -99.202408
# 1729                                     REAL DEL MONTE  19.396245 -99.200541
# 1730                                 PRIVADA CENTENARIO  19.361358 -99.229676
# 1731                                   PONCIANO ARRIAGA  19.355752 -99.225808
# 1732                                   LOMAS DE BECERRA  19.384622 -99.217050
# 1733                                   LOMAS DE TARANGO  19.363631 -99.215223
# 1734                            LA PRESA SECCION HORNOS  19.382113 -99.215751
# 1735                                       LAS CUEVITAS  19.386787 -99.225770
# 1736                                             ARVIDE  19.381666 -99.203305
# 1737                                          ATLAMAXAC  19.356137 -99.247346
# 1738                               LOMAS DE SANTA FE II  19.368131 -99.258695
# 1739                                       VILLA VERDUN  19.338631 -99.256628
# 1740                                       BUENAVISTA I  19.449614 -99.149596
# 1741                                         LA CASCADA  19.369339 -99.202309
# 1742                           ESTADO DE HIDALGO (AMPL)  19.397715 -99.209054
# 1743                                 DE TARANGO (RCNDA)  19.362536 -99.222212
# 1744                                        PANTITLAN V  19.406159 -99.060305
# 1745                                        SANTA ANITA  19.401178 -99.120864
# 1746                                SAN ANTONIO (FRACC)  19.480175 -99.204882
# 1747                                         SAN RAFAEL  19.486455 -99.187990
# 1748                                        NUEVA ESPAA  19.498125 -99.187192
# 1749                                  POTRERO DEL LLANO  19.474663 -99.160674
# 1750                            SAN SALVADOR XOCHIMANCA  19.459556 -99.173566
# 1751                                         MONTE ALTO  19.479964 -99.156328
# 1752                          SAN PEDRO XALPA (AMPL) II  19.475910 -99.217041
# 1753                  HACIENDA DE GUADALUPE CHIMALISTAC  19.349653 -99.182508
# 1754                                       PRO HOGAR II  19.476354 -99.155970
# 1755                        VILLAS AZCAPOTZALCO (U HAB)  19.489781 -99.192023
# 1756                            LOMAS DE SAN LORENZO II  19.320756 -99.067174
# 1757                  DESARROLLO URBANO QUETZALCOATL  I  19.333066 -99.040300
# 1758                     SANTA MARIA AZTAHUACAN (EJ) II  19.349846 -99.032968
# 1759                                            XALPA I  19.327467 -99.015186
# 1760                                        AMADO NERVO  19.368283 -99.295103
# 1761                                     JUAN ESCUTIA I  19.395526 -99.050664
# 1762                                   SAN JUAN XALPA I  19.337420 -99.083457
# 1763                      EJERCITO DE ORIENTE (U HAB) I  19.369278 -99.026049
# 1764                             CONSTITUCION DE 1917 I  19.349581 -99.064249
# 1765                            CERRO DE LA ESTRELLA II  19.321621 -99.077398
# 1766  9 1/2 - FRANCISCO VILLA (EJERCITO CONSTITUCION...  19.376866 -99.050771
# 1767                                            PARAISO  19.377589 -99.031424
# 1768                                 SAN ANTONIO (BARR)  19.305873 -99.073211
# 1769                             SANTA CRUZ VII (U HAB)  19.313533 -99.046021
# 1770                                          MIRAVALLE  19.331482 -98.995850
# 1771                                          LA PLANTA  19.294250 -99.063877
# 1772                     LOMAS ESTRELLA 1A SECC (FRACC)  19.324595 -99.094351
# 1773                               MEXICALTZINGO (PBLO)  19.358215 -99.120000
# 1774                               NORMA ISSSTE (U HAB)  19.363700 -99.076744
# 1775                                         JACARANDAS  19.346277 -99.051756
# 1776                                      ESCUADRON 201  19.363596 -99.112266
# 1777                      GUELATAO DE JUAREZ II (U HAB)  19.384063 -99.044580
# 1778                                    JESUS DEL MONTE  19.366428 -99.293760
# 1779                        LOMAS DE SAN BERNABE (AMPL)  19.307329 -99.270190
# 1780                                  PUEBLO NUEVO BAJO  19.306936 -99.245344
# 1781                              PLAZUELA DEL PEDREGAL  19.303454 -99.232260
# 1782                                            ACTIPAN  19.369882 -99.178167
# 1783                                EL SANTUARIO (AMPL)  19.342502 -99.089666
# 1784                                             CACAMA  19.359111 -99.125442
# 1785                                            EL EDEN  19.364694 -99.013275
# 1786  EJTO CONSTITUCIONALISTA, SUPERMANZANA II ( U HAB)  19.386478 -99.056778
# 1787                       CABEZA DE JUAREZ III (U HAB)  19.383301 -99.041690
# 1788                         CABEZA DE JUAREZ I (U HAB)  19.384990 -99.044080
# 1789                                            GRANADA  19.439913 -99.193133
# 1790                                        VALLE GOMEZ  19.456869 -99.119010
# 1791                                             PUEBLA  19.409390 -99.082271
# 1792                                  MICHOACANA (AMPL)  19.448324 -99.113076
# 1793                                   TRES MOSQUETEROS  19.440627 -99.106422
# 1794                            EMILIANO ZAPATA (U HAB)  19.432812 -99.120128
# 1795                                         POPOTLA II  19.452597 -99.179438
# 1796                                       COUNTRY CLUB  19.351245 -99.140371
# 1797                                         EL CARACOL  19.304480 -99.163683
# 1798                INTEGRACION LATINOAMERICANA (U HAB)  19.338313 -99.179321
# 1799                 EX EJIDO SAN FRANCISCO CULHUACAN I  19.331904 -99.129083
# 1800                          CTM IXA CULHUACAN (U HAB)  19.310976 -99.106036
# 1801                      EL PARQUE DE COYOACAN (FRACC)  19.311148 -99.130813
# 1802                           STUNAM CULHUACAN (U HAB)  19.321166 -99.102249
# 1803                                   SAN MATEO (BARR)  19.351901 -99.148280
# 1804                              SANTA URSULA COYOACAN  19.303628 -99.172574
# 1805                     CTM IX CULHUACAN 32-33 (U HAB)  19.309503 -99.102840
# 1806                              AVIACION CIVIL (AMPL)  19.411745 -99.076522
# 1807                            ADOLFO RUIZ CORTINES II  19.317844 -99.155072
# 1808                               EL ARENAL 1A SECCION  19.425061 -99.063320
# 1809                                AERONAUTICA MILITAR  19.420865 -99.115752
# 1810                                IGNACIO ZARAGOZA II  19.411779 -99.087917
# 1811                             20 DE NOVIEMBRE (AMPL)  19.443637 -99.114512

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'WYAEZZVT00PMD0KJIHOFRGBAQXFI0UMRTDKQWGLKABOWBVL0' # your Foursquare ID
CLIENT_SECRET = 'EEMR5CG1PFXABI4PNF1CPGFNIBQ3VAO4U1LJ230KAPJZIV1L' # your Foursquare Secret
VERSION = '20180605' 

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WYAEZZVT00PMD0KJIHOFRGBAQXFI0UMRTDKQWGLKABOWBVL0
# CLIENT_SECRET:EEMR5CG1PFXABI4PNF1CPGFNIBQ3VAO4U1LJ230KAPJZIV1L

# %%
neighborhood_lat = df.loc[0, 'Latitude'] # neighborhood latitude value
neighborhood_long = df.loc[0, 'Longitude'] # neighborhood longitude value

# %%
neighborhood_name = df.loc[0, 'Neighbourhood'] # neighborhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_lat, 
                                                               neighborhood_long))
# Out:
# Latitude and longitude values of MIGUEL HIDALGO are 19.4016815485,  -99.2354719599.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_lat, 
    neighborhood_long, 
    radius, 
    LIMIT)
print('Esta es la url:', url) # display URL
# Out:
# Esta es la url: https://api.foursquare.com/v2/venues/explore?&client_id=WYAEZZVT00PMD0KJIHOFRGBAQXFI0UMRTDKQWGLKABOWBVL0&client_secret=EEMR5CG1PFXABI4PNF1CPGFNIBQ3VAO4U1LJ230KAPJZIV1L&v=20180605&ll=19.4016815485, -99.2354719599&radius=500&limit=100

# %%
results = requests.get(url).json()
results
open('results.JSON') as data_file:
        data=json.load(data_file)
normalized_df = pd.io.json.json_normalize(data)
normalized_df.to_csv('my_csv_file.csv',index=False)
# Out:
# {'meta': {'code': 200, 'requestId': '5dc8af98f96b2c002c1c584e'},
#  'response': {'headerLocation': 'Miguel Hidalgo',
#   'headerFullLocation': 'Miguel Hidalgo, Mexico City',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 4,
#   'suggestedBounds': {'ne': {'lat': 19.406181553000007,
#     'lng': -99.23070993593554},
#    'sw': {'lat': 19.397181543999995, 'lng': -99.24023398386446}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5c29b41495cac41936f7dd',
#        'name': 'Flores Del Bosque',
#        'location': {'lat': 19.40066209833531,
#         'lng': -99.23317805788683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.40066209833531,
#           'lng': -99.23317805788683}],
#         'distance': 266,
#         'cc': 'MX',
#         'city': 'Ciudad de México',
#         'state': 'Distrito Federal',
#         'country': 'México',
#         'formattedAddress': ['Ciudad de México, Distrito Federal', 'México']},
#        'categories': [{'id': '4bf58dd8d48988d11b951735',
#          'name': 'Flower Shop',
#          'pluralName': 'Flower Shops',
#          'shortName': 'Flower Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/flowershop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e5c29b41495cac41936f7dd-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '504f3122e4b0a4306aead5f9',
#        'name': 'K-vitacion',
#        'location': {'lat': 19.40246684644411,
#         'lng': -99.23264771368717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.40246684644411,
#           'lng': -99.23264771368717}],
#         'distance': 309,
#         'cc': 'MX',
#         'country': 'México',
#         'formattedAddress': ['México']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-504f3122e4b0a4306aead5f9-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d24eb5ff50aa35dd3fc2f9f',
#        'name': 'Nine West',
#        'location': {'address': 'CC Duraznos',
#         'lat': 19.40350103920329,
#         'lng': -99.23888125408124,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.40350103920329,
#           'lng': -99.23888125408124}],
#         'distance': 411,
#         'cc': 'MX',
#         'city': 'Ciudad de México',
#         'state': 'Distrito Federal',
#         'country': 'México',
#         'formattedAddress': ['CC Duraznos',
#          'Ciudad de México, Distrito Federal',
#          'México']},
#        'categories': [{'id': '4bf58dd8d48988d107951735',
#          'name': 'Shoe Store',
#          'pluralName': 'Shoe Stores',
#          'shortName': 'Shoes',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_shoestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d24eb5ff50aa35dd3fc2f9f-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bce2cde4b0a8f8e00d2fe9',
#        'name': 'Plaza de la Radio',
#        'location': {'address': 'Glorieta Bosques de las Lomas',
#         'lat': 19.40556776316402,
#         'lng': -99.23332948372602,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 19.40556776316402,
#           'lng': -99.23332948372602}],
#         'distance': 487,
#         'postalCode': '117000',
#         'cc': 'MX',
#         'city': 'Ciudad de México',
#         'state': 'Distrito Federal',
#         'country': 'México',
#         'formattedAddress': ['Glorieta Bosques de las Lomas',
#          '117000 Ciudad de México, Distrito Federal',
#          'México']},
#        'categories': [{'id': '4deefb944765f83613cdba6e',
#          'name': 'Historic Site',
#          'pluralName': 'Historic Sites',
#          'shortName': 'Historic Site',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/historicsite_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50bce2cde4b0a8f8e00d2fe9-3'}]}]}}

# %%
results
with open('D:\curso Coursera\Curso 9 Proyecto Final\Semana 5\Capstone Project The Battle of Neighborhood Part 2\cdmx02.json', 'w') as json_file:
    json.dump(results, json_file)

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Now we are ready to clean the json and structure it into a pandas dataframe.
venues = results['response']['groups'][0]['items']

# %%
nearby_venues = json_normalize(venues) # flatten JSON

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# %%
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# %%
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

print('Mas cercanos', nearby_venues.head())
# Out:
# Mas cercanos                 name     categories        lat        lng
# 0  Flores Del Bosque    Flower Shop  19.400662 -99.233178
# 1         K-vitacion            Spa  19.402467 -99.232648
# 2          Nine West     Shoe Store  19.403501 -99.238881
# 3  Plaza de la Radio  Historic Site  19.405568 -99.233329

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 4 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
cdmx_venues = getNearbyVenues(names=df['Neighbourhood'],latitudes=df['Latitude'], longitudes=df['Longitude'])
# Out:
# MIGUEL HIDALGO
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-238-cf77d4285805> in <module>
# ----> 1 cdmx_venues = getNearbyVenues(names=df['Neighbourhood'],latitudes=df['Latitude'], longitudes=df['Longitude'])
#
# <ipython-input-226-8c9a08363335> in getNearbyVenues(names, latitudes, longitudes, radius)
#      16
#      17         # make the GET request
# ---> 18         results = requests.get(url).json()["response"]['groups'][0]['items']
#      19
#      20         # return only relevant information for each nearby venue
#
# KeyError: 'groups'

# %%
results['response']['groups'][0]['items']
results['response']
#check the size of the resulting dataframe
print(cdmx_venues.shape())
print(cdmx_venues.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-236-93754af04244> in <module>
#       2 results['response']
#       3 #check the size of the resulting dataframe
# ----> 4 print(cdmx_venues.shape())
#       5 print(cdmx_venues.head())
#
# NameError: name 'cdmx_venues' is not defined

# %% [markdown]
# Check how many venues were returned for each neighborhood

# %%
print(cdmx_venues.groupby('Neighborhood').count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-233-5aad374d710e> in <module>
# ----> 1 print(cdmx_venues.groupby('Neighborhood').count())
#
# NameError: name 'cdmx_venues' is not defined

# %% [markdown]
# Find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(cdmx_venues['Venue Category'].unique())))

# %% [markdown]
# Analyze Each Neighborhood

# %%
cdmx_onehot = pd.get_dummies(cdmx_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
cdmx_onehot['Neighborhood'] = cdmx_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [cdmx_onehot.columns[-1]] + list(cdmx_onehot.columns[:-1])
cdmx_onehot = cdmx_onehot[fixed_columns]

print(cdmx_onehot.head)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-234-7c0a614feead> in <module>
# ----> 1 cdmx_onehot = pd.get_dummies(cdmx_venues[['Venue Category']], prefix="", prefix_sep="")
#       2
#       3 # add neighborhood column back to dataframe
#       4 cdmx_onehot['Neighborhood'] = cdmx_venues['Neighborhood']
#       5
#
# NameError: name 'cdmx_venues' is not defined

# %% [markdown]
# examine the new dataframe size.

# %%
print(cdmx_onehot.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-235-c1c943a6541d> in <module>
# ----> 1 print(cdmx_onehot.shape)
#
# NameError: name 'cdmx_onehot' is not defined

# %% [markdown]
# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
cdmx_grouped = cdmx_onehot.groupby('Neighborhood').mean().reset_index()
cdmx_grouped

# %% [markdown]
# Confirming the new size of the table

# %%
cdmx_grouped.shape

# %% [markdown]
# Lets print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in cdmx_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = cdmx_grouped[cdmx_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')

# %% [markdown]
# Let´s put that into a pandas dataframe

# %%
#First, let's write a function to sort the venues in descending orde
    
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 2

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)

neighborhoods_venues_sorted['Neighborhood'] = cdmx_grouped['Neighborhood']
print('sort', neighborhoods_venues_sorted)
for ind in np.arange(cdmx_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(cdmx_grouped.iloc[ind, :], num_top_venues)

print(neighborhoods_venues_sorted.head(7))

# %% [markdown]
# Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = cdmx_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_

# %% [markdown]
# Create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood

# %%
#Add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
cdmx_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
cdmx_merged  = cdmx_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighbourhood')

cdmx_merged = cdmx_merged.reset_index(drop=True)

cdmx_merged

# %% [markdown]
# visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(cdmx_merged['Latitude'], cdmx_merged['Longitude'], cdmx_merged['Neighbourhood'], cdmx_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    cluster = int(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters.save("map_clusters_mexicocity.html ")
map_clusters

# %% [markdown]
# Examine Clusters

# %% [markdown]
# 1st Cluster

# %%
cdmx_merged.loc[cdmx_merged['Cluster Labels'] == 0, cdmx_merged.columns[[1] + list(range(5, cdmx_merged.shape[1]))]]

# %% [markdown]
# 2nd Cluster

# %%
cdmx_merged.loc[cdmx_merged['Cluster Labels'] == 1, cdmx_merged.columns[[1] + list(range(5, cdmx_merged.shape[1]))]]

# %% [markdown]
# 3rd Cluster

# %%
cdmx_merged.loc[cdmx_merged['Cluster Labels'] == 2, cdmx_merged.columns[[1] + list(range(5, cdmx_merged.shape[1]))]]

# %% [markdown]
# 4th Cluster

# %%
cdmx_merged.loc[cdmx_merged['Cluster Labels'] == 3, cdmx_merged.columns[[1] + list(range(5, cdmx_merged.shape[1]))]]

# %% [markdown]
# 5th Cluster

# %%
cdmx_merged.loc[cdmx_merged['Cluster Labels'] == 4, cdmx_merged.columns[[1] + list(range(5, cdmx_merged.shape[1]))]]
